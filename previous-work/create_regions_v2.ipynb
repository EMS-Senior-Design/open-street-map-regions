# %%
# unzip input file first

import xml.etree.ElementTree as ET
import requests
import math
import pprint
import time
import numpy as np
import pandas as pd

# %% [markdown]
# ## Travis County Boundary API

# %%
response = requests.get("https://geo.traviscountytx.gov/arcgis/rest/services/TNR/TravisCountyBoundary/MapServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json")

# %%
boundary = response.json()['features'][0]['geometry']['paths'][0]
pprint.pprint(boundary[0])
# Out:
# [-98.02690146055397, 30.25180859020622]

# %%
latitudes = []
longitudes = []

for coord in boundary:
    longitudes.append(coord[0])
    latitudes.append(coord[1])
    
print(len(longitudes))
print(len(latitudes))
# Out:
# 213
# 213

# %% [markdown]
# ## Region Mapping

# %%
LATITUDE_MILES = 69
LONGITUDE_MILES = 54.6

vertical_distance = (max(latitudes) - min(latitudes))*LATITUDE_MILES
horizontal_distance = (max(longitudes) - min(longitudes))*LONGITUDE_MILES

# %%
# Assuming we want to make 400 squares, how should we partition the vertically/horizontally
NUM_REGIONS = 400
square_len = (vertical_distance*horizontal_distance/NUM_REGIONS)**0.5

# %%
latitude_delta = square_len/LATITUDE_MILES
longitude_delta = square_len/LONGITUDE_MILES
longitude_delta
# Out:
# 0.03918197759635523

# %%
lat_lon = zip(latitudes, longitudes)

# %%
min_lat = min(latitudes)
min_lon = min(longitudes)
max_lat = max(latitudes)
max_lon = max(longitudes)
nrows = math.ceil((max_lat - min_lat) / latitude_delta)
ncols = math.ceil((max_lon - min_lon) / longitude_delta)
def map_point_to_region(latitude, longitude):
    return math.floor((latitude-min_lat)/latitude_delta) * ncols  + math.floor((longitude-min_lon)/longitude_delta)

# %%
def get_representative(region_num): # 8 cols per row, # R10 --> row_num = 1, col_num = 2
    row_num = region_num//ncols # Correct
    col_num = region_num - row_num*ncols
    lat = min_lat + row_num * latitude_delta + 0.5*latitude_delta
    lon = min_lon + col_num * longitude_delta + 0.5*longitude_delta
    return [lon, lat]

# %%
map_point_to_region(30.084446, -97.702885)
# Out:
# 33

# %%
get_representative(13)
# Out:
# [-97.6441785574555, 30.038787023039202]

# %%
region_coords = [get_representative(i) for i in range(400)]
pprint.pprint(region_coords)
# Out:
# [[-98.15354426620812, 30.038787023039202],
#  [-98.11436228861176, 30.038787023039202],
#  [-98.0751803110154, 30.038787023039202],
#  [-98.03599833341904, 30.038787023039202],
#  [-97.99681635582269, 30.038787023039202],
#  [-97.95763437822635, 30.038787023039202],
#  [-97.91845240062999, 30.038787023039202],
#  [-97.87927042303363, 30.038787023039202],
#  [-97.84008844543727, 30.038787023039202],
#  [-97.80090646784092, 30.038787023039202],
#  [-97.76172449024456, 30.038787023039202],
#  [-97.7225425126482, 30.038787023039202],
#  [-97.68336053505185, 30.038787023039202],
#  [-97.6441785574555, 30.038787023039202],
#  [-97.60499657985915, 30.038787023039202],
#  [-97.56581460226279, 30.038787023039202],
#  [-97.52663262466643, 30.038787023039202],
#  [-97.48745064707008, 30.038787023039202],
#  [-97.44826866947372, 30.038787023039202],
#  [-97.40908669187736, 30.038787023039202],
#  [-97.369904714281, 30.038787023039202],
#  [-98.15354426620812, 30.069791892267624],
#  [-98.11436228861176, 30.069791892267624],
#  [-98.0751803110154, 30.069791892267624],
#  [-97.95763437822635, 30.596874669150765],
#  [-97.91845240062999, 30.596874669150765],
#  [-97.87927042303363, 30.596874669150765],
#  [-97.84008844543727, 30.596874669150765],
#  [-97.80090646784092, 30.596874669150765],
#  [-97.76172449024456, 30.596874669150765],
#  [-97.7225425126482, 30.596874669150765],
#  [-97.68336053505185, 30.596874669150765],
#  [-97.6441785574555, 30.596874669150765],
#  [-97.60499657985915, 30.596874669150765],
#  [-97.56581460226279, 30.596874669150765],
#  [-97.52663262466643, 30.596874669150765],
#  [-97.48745064707008, 30.596874669150765],
#  [-97.44826866947372, 30.596874669150765],
#  [-97.40908669187736, 30.596874669150765],
#  [-97.369904714281, 30.596874669150765],
#  [-98.15354426620812, 30.627879538379187]]

# %% [markdown]
# ## EMS Stations

# %%
# Read in data
ems_data = pd.read_excel("ems_facilities_2020Aug12.xlsx")
print(ems_data.shape)

# Filter data
facility_type = ['Medic Station', 'Demand Medic Station']
ems_data = ems_data[ems_data['FACILITY_TYPE'].isin(facility_type)]
print(ems_data.shape)

# Get coords
ems_longitudes = ems_data['LONGITUDE']
ems_latitudes = ems_data['LATITUDE']

ems_coords = [list(c) for c in zip(ems_longitudes, ems_latitudes)]
pprint.pprint(ems_coords)
# Out:
# (51, 30)
# (44, 30)
# [[-97.7217247499999, 30.25948737],
#  [-97.8602694099999, 30.15636358],
#  [-97.7503950699999, 30.24662518],
#  [-97.6615917999999, 30.32339149],
#  [-97.7482999999999, 30.265327],
#  [-97.7259999999999, 30.326725],
#  [-97.9295778989999, 30.39848581],
#  [-97.7678132899999, 30.22977355],
#  [-97.8054399999999, 30.206495],
#  [-97.7343149999999, 30.274637],
#  [-97.6842324899999, 30.27824902],
#  [-97.7264146799999, 30.32672533],
#  [-97.7394194699999, 30.26582831],
#  [-97.7231080899999, 30.37236405],
#  [-97.7588594799999, 30.33455506],
#  [-97.9348469179999, 30.302810828],
#  [-97.7427673899999, 30.41819953],
#  [-97.8535901899999, 30.22782184],
#  [-97.7132197299999, 30.2292149],
#  [-97.6784999999999, 30.35271081],
#  [-97.6895245299999, 30.32525961],
#  [-97.7936091899999, 30.17470861],
#  [-97.8368195599999, 30.40433212],
#  [-97.7725225199999, 30.27734164],
#  [-97.6923538799999, 30.38399792],
#  [-97.8018875799999, 30.44651026],
#  [-97.8239838099999, 30.13933909],
#  [-97.8200249299999, 30.27945028],
#  [-98.0006876299999, 30.43210206],
#  [-97.5612131399999, 30.34180422],
#  [-97.7443559999999, 30.0997659999999],
#  [-97.9225452899999, 30.49262833],
#  [-98.066519, 30.3555008],
#  [-97.9685019359999, 30.346232091],
#  [-97.7424767099999, 30.18690915],
#  [-97.6532561099999, 30.39952596],
#  [-97.6557479799999, 30.21606195],
#  [-97.8975703899999, 30.18291397],
#  [-97.9197071299999, 30.23950007],
#  [-97.7092092399999, 30.29974433],
#  [-97.7657451699999, 30.48172221],
#  [-97.6131239699999, 30.3470128],
#  [-97.6436239999999, 30.157544],
#  [-97.5826048799999, 30.24623636]]

# %% [markdown]
# ## Hospital Locations

# %%
BingMapsKey = "AgmNkDXiPX65nDUv6MUa0gRtHyrrGAMuD5n8mNQfl72ISI6xGZA37clQ0OcP56y-"

# Example
call = requests.get("https://dev.virtualearth.net/REST/v1/LocalSearch/?query=hospital&userLocation=47.602038,-122.333964&key=" + BingMapsKey)
pprint.pprint(call.json())
# Out:
# {'authenticationResultCode': 'ValidCredentials',
#  'brandLogoUri': 'http://dev.virtualearth.net/Branding/logo_powered_by.png',
#  'copyright': 'Copyright © 2020 Microsoft and its suppliers. All rights '
#               'reserved. This API cannot be accessed and the content and any '
#               'results may not be used, reproduced or transmitted in any '
#               'manner without express written permission from Microsoft '
#               'Corporation.',
#  'resourceSets': [{'estimatedTotal': 10,
#                    'resources': [{'Address': {'addressLine': '1100 9th Ave',
#                                               'adminDistrict': 'WA',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '1100 9th '
#                                                                   'Ave, '
#                                                                   'Seattle, '
#                                                                   'WA, 98101',
#                                               'locality': 'Seattle',
#                                               'postalCode': '98101'},
#                                   'PhoneNumber': '(206) 223-6600',
#                                   'Website': 'https://www.virginiamason.org/seattle',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [47.61003112792969,
#                                                                      -122.3274154663086],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Virginia Mason Hospital and Seattle '
#                                           'Medical Center',
#                                   'point': {'coordinates': [47.61003112792969,
#                                                             -122.3274154663086],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '1101 Madison St '
#                                                              '#700',
#                                               'adminDistrict': 'WA',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '1101 '
#                                                                   'Madison St '
#                                                                   '#700, '
#                                                                   'Seattle, '
#                                                                   'WA, 98104',
#                                               'locality': 'Seattle',
#                                               'postalCode': '98104'},
#                                   'PhoneNumber': '(206) 386-3723',
#                                   'Website': 'https://www.swedish.org/?y_source=1_OTU3Njc4NC00ODMtbG9jYXRpb24ud2Vic2l0ZQ%3D%3D#llaid=8177',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [47.60883331298828,
#                                                                      -122.32198333740234],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Swedish Medical Center',
#                                   'point': {'coordinates': [47.60883331298828,
#                                                             -122.32198333740234],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '747 Broadway',
#                                               'adminDistrict': 'WA',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '747 '
#                                                                   'Broadway, '
#                                                                   'Seattle, '
#                                                                   'WA, 98122',
#                                               'locality': 'Seattle',
#                                               'postalCode': '98122'},
#                                   'PhoneNumber': '(206) 386-6000',
#                                   'Website': 'https://www.swedish.org/locations/first-hill-campus#llaid=7437',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [47.608741760253906,
#                                                                      -122.32170104980469],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Swedish Hospital - First Hill East '
#                                           'Medical Tower',
#                                   'point': {'coordinates': [47.608741760253906,
#                                                             -122.32170104980469],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '1334 Terry Ave',
#                                               'adminDistrict': 'WA',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '1334 Terry '
#                                                                   'Ave, '
#                                                                   'Seattle, '
#                                                                   'WA, 98101',
#                                               'locality': 'Seattle',
#                                               'postalCode': '98101'},
#                                   'PhoneNumber': '(206) 682-2661',
#                                   'Website': 'https://www.kindredhealthcare.com/locations/transitional-care-hospitals/kindred-hospital-seattle-first-hill',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [47.6119384765625,
#                                                                      -122.32862854003906],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Kindred Hospital Seattle - First '
#                                           'Hill',
#                                   'point': {'coordinates': [47.6119384765625,
#                                                             -122.32862854003906],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '325 9th Ave',
#                                               'adminDistrict': 'WA',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '325 9th '
#                                                                   'Ave, '
#                                                                   'Seattle, '
#                                                                   'WA, 98104',
#                                               'locality': 'Seattle',
#                                               'postalCode': '98104'},
#                                   'PhoneNumber': '(206) 744-3076',
#                                   'Website': 'https://www.uwmedicine.org/locations/psychiatric-emergency-harborview?utm_source=google&utm_medium=organic&utm_campaign=local_seo',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [47.604007720947266,
#                                                                      -122.32418060302734],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Psychiatric Emergency Services at '
#                                           'harborview',
#                                   'point': {'coordinates': [47.60420227050781,
#                                                             -122.32352447509766],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '325 9th Ave',
#                                               'adminDistrict': 'WA',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '325 9th '
#                                                                   'Ave, '
#                                                                   'Seattle, '
#                                                                   'WA, 98104',
#                                               'locality': 'Seattle',
#                                               'postalCode': '98104'},
#                                   'PhoneNumber': '(206) 520-5000',
#                                   'Website': 'http://www.uwmedicine.org/locations/lipid-northwest-harborview?utm_source=google&utm_medium=local&utm_campaign=sheet',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [47.60394287109375,
#                                                                      -122.32415008544922],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'UW Lipid Clinic at South Lake Union',
#                                   'point': {'coordinates': [47.60420227050781,
#                                                             -122.32352447509766],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '360 8Th Ave',
#                                               'adminDistrict': 'WA',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '360 8Th '
#                                                                   'Ave, '
#                                                                   'Seattle, '
#                                                                   'WA, 98104',
#                                               'locality': 'Seattle',
#                                               'postalCode': '98104'},
#                                   'PhoneNumber': '(206) 744-3254',
#                                   'Website': 'http://uwmedicine.org/',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [47.602535247802734,
#                                                                      -122.32234954833984],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Harborview Medical Center',
#                                   'point': {'coordinates': [47.602569580078125,
#                                                             -122.32239532470703],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '325 9th Ave Ste '
#                                                              '2NJB244',
#                                               'adminDistrict': 'WA',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '325 9th Ave '
#                                                                   'Ste '
#                                                                   '2NJB244, '
#                                                                   'Seattle, '
#                                                                   'WA, 98104',
#                                               'locality': 'Seattle',
#                                               'postalCode': '98104'},
#                                   'PhoneNumber': '(206) 744-3145',
#                                   'Website': 'https://www.uwmedicine.org/',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [47.60394287109375,
#                                                                      -122.32415008544922],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'University Of Washington Pathology',
#                                   'point': {'coordinates': [47.60420227050781,
#                                                             -122.32352447509766],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '325 9th Ave',
#                                               'adminDistrict': 'WA',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '325 9th '
#                                                                   'Ave, '
#                                                                   'Seattle, '
#                                                                   'WA, 98104',
#                                               'locality': 'Seattle',
#                                               'postalCode': '98104'},
#                                   'PhoneNumber': '(206) 744-3123',
#                                   'Website': 'http://www.uwmedicine.org/locations/nontuberculous-mycobacterial-disease-harborview?utm_source=google&utm_medium=local&utm_campaign=sheet',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [47.60394287109375,
#                                                                      -122.32415008544922],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Nontuberculous Mycobacterial '
#                                           'Disease Clinic at Harborview',
#                                   'point': {'coordinates': [47.60420227050781,
#                                                             -122.32352447509766],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '410 9th Ave 7th '
#                                                              'Floor',
#                                               'adminDistrict': 'WA',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '410 9th Ave '
#                                                                   '7th Floor, '
#                                                                   'Seattle, '
#                                                                   'WA, 98104',
#                                               'locality': 'Seattle',
#                                               'postalCode': '98104'},
#                                   'PhoneNumber': '(206) 520-5000',
#                                   'Website': 'http://www.uwmedicine.org/locations/chest-at-harborview?utm_source=google&utm_medium=local&utm_campaign=sheet',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [47.604732513427734,
#                                                                      -122.32354736328125],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Chest Clinic at Harborview',
#                                   'point': {'coordinates': [47.604732513427734,
#                                                             -122.32354736328125],
#                                             'type': 'Point'}}]}],
#  'statusCode': 200,
#  'statusDescription': 'OK',
#  'traceId': '19379ab20a4e49aeaca59db98ae2cae4|CH000010A3|0.0.0.0'}

# %%
query = "hospital"

# Need to negate second coordinate
area = "30.2672,97.7431"
#29.7604,-95.3698

#call = requests.get("https://dev.virtualearth.net/REST/v1/LocalSearch/?query=" + query + "&userLocation=" + area + "&key=" + BingMapsKey)
#call = requests.get("https://dev.virtualearth.net/REST/v1/LocalSearch/?query=coffee&userLocation=30.2672,97.7431&key=" + BingMapsKey)

call = requests.get("https://dev.virtualearth.net/REST/v1/LocalSearch/?type=Hospitals&userLocation=30.2672,-97.7431&maxResults=25&key=" + BingMapsKey)
#call = requests.get("https://dev.virtualearth.net/REST/v1/LocalSearch/?query=hospital&userLocation=30.2672,-97.7431&maxResults=25&key=" + BingMapsKey)

pprint.pprint(call.json())
# Out:
# {'authenticationResultCode': 'ValidCredentials',
#  'brandLogoUri': 'http://dev.virtualearth.net/Branding/logo_powered_by.png',
#  'copyright': 'Copyright © 2020 Microsoft and its suppliers. All rights '
#               'reserved. This API cannot be accessed and the content and any '
#               'results may not be used, reproduced or transmitted in any '
#               'manner without express written permission from Microsoft '
#               'Corporation.',
#  'resourceSets': [{'estimatedTotal': 23,
#                    'resources': [{'Address': {'addressLine': '4534 W Gate Blvd '
#                                                              'Ste 100',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '4534 W Gate '
#                                                                   'Blvd Ste '
#                                                                   '100, '
#                                                                   'Austin, TX, '
#                                                                   '78745',
#                                               'locality': 'Austin',
#                                               'postalCode': '78745'},
#                                   'PhoneNumber': '(512) 892-4463',
#                                   'Website': 'http://www.westgatepetandbird.com/',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [30.23076629638672,
#                                                                      -97.80225372314453],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Westgate Pet & Bird Hospital',
#                                   'point': {'coordinates': [30.23076629638672,
#                                                             -97.80225372314453],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '2414-B S Lamar '
#                                                              'Blvd',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '2414-B S '
#                                                                   'Lamar Blvd, '
#                                                                   'Austin, TX, '
#                                                                   '78704',
#                                               'locality': 'Austin',
#                                               'postalCode': '78704'},
#                                   'PhoneNumber': '(512) 441-3192',
#                                   'Website': 'https://www.bluebonnetah.com/',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [30.24726104736328,
#                                                                      -97.77750396728516],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Bluebonnet Animal Hospital',
#                                   'point': {'coordinates': [30.246864318847656,
#                                                             -97.77732849121094],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '615 W Slaughter '
#                                                              'Ln Ste 121',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '615 W '
#                                                                   'Slaughter '
#                                                                   'Ln Ste 121, '
#                                                                   'Austin, TX, '
#                                                                   '78748',
#                                               'locality': 'Austin',
#                                               'postalCode': '78748'},
#                                   'PhoneNumber': '(512) 386-1065',
#                                   'Website': 'https://southparkaustin.com/',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [30.1719913482666,
#                                                                      -97.80118560791016],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'South Park Animal Hospital',
#                                   'point': {'coordinates': [30.17304229736328,
#                                                             -97.80033111572266],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '2707 S Austin '
#                                                              'Ave',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '2707 S '
#                                                                   'Austin Ave, '
#                                                                   'Georgetown, '
#                                                                   'TX, 78626',
#                                               'locality': 'Georgetown',
#                                               'postalCode': '78626'},
#                                   'PhoneNumber': '(512) 863-3563',
#                                   'Website': 'https://gtvet.com/contact',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [30.61953353881836,
#                                                                      -97.68008422851562],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Georgetown Veterinary Hospital',
#                                   'point': {'coordinates': [30.61981201171875,
#                                                             -97.68097686767578],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '1500 Red River '
#                                                              'St',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '1500 Red '
#                                                                   'River St, '
#                                                                   'Austin, TX, '
#                                                                   '78701',
#                                               'locality': 'Austin',
#                                               'postalCode': '78701'},
#                                   'PhoneNumber': '(512) 324-7010',
#                                   'Website': 'https://healthcare.ascension.org/Locations/Texas/TXAUS/Austin-Dell-Seton-Medical-Center-at-The-University-of-Texas',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [30.276596069335938,
#                                                                      -97.7340087890625],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Dell Seton Medical Center at The '
#                                           'University of Texas',
#                                   'point': {'coordinates': [30.275590896606445,
#                                                             -97.73481750488281],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '2021 W State '
#                                                              'Highway 46 Ste '
#                                                              '103',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '2021 W '
#                                                                   'State '
#                                                                   'Highway 46 '
#                                                                   'Ste 103, '
#                                                                   'New '
#                                                                   'Braunfels, '
#                                                                   'TX, 78132',
#                                               'locality': 'New Braunfels',
#                                               'postalCode': '78132'},
#                                   'PhoneNumber': '(830) 620-6005',
#                                   'Website': 'http://www.tworiverseyecare.com/',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [29.72032356262207,
#                                                                      -98.17103576660156],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Two Rivers Eye Care',
#                                   'point': {'coordinates': [29.72076416015625,
#                                                             -98.17084503173828],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '1536 E Anderson '
#                                                              'Lane',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '1536 E '
#                                                                   'Anderson '
#                                                                   'Lane, '
#                                                                   'Austin, TX, '
#                                                                   '78752',
#                                               'locality': 'Austin',
#                                               'postalCode': '78752'},
#                                   'PhoneNumber': '(512) 832-4119',
#                                   'Website': 'https://austinanimed.com/',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [30.332632064819336,
#                                                                      -97.6845932006836],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Animal Medical Center of Austin',
#                                   'point': {'coordinates': [30.332632064819336,
#                                                             -97.6845932006836],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '4606 Spicewood '
#                                                              'Springs Rd',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '4606 '
#                                                                   'Spicewood '
#                                                                   'Springs Rd, '
#                                                                   'Austin, TX, '
#                                                                   '78759',
#                                               'locality': 'Austin',
#                                               'postalCode': '78759'},
#                                   'PhoneNumber': '(512) 345-2727',
#                                   'Website': 'http://spicewoodanimalhospital.com/',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [30.3754825592041,
#                                                                      -97.76058959960938],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Spicewood Springs Animal',
#                                   'point': {'coordinates': [30.375274658203125,
#                                                             -97.76069641113281],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '1201 W 38th St',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '1201 W 38th '
#                                                                   'St, Austin, '
#                                                                   'TX, 78705',
#                                               'locality': 'Austin',
#                                               'postalCode': '78705'},
#                                   'PhoneNumber': '(512) 324-1000',
#                                   'Website': 'https://healthcare.ascension.org/Locations/Texas/TXAUS/Austin-Ascension-Seton-Medical-Center-Austin',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [30.304731369018555,
#                                                                      -97.74609375],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Ascension Seton Medical Center '
#                                           'Austin',
#                                   'point': {'coordinates': [30.304731369018555,
#                                                             -97.74609375],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '4900 Mueller '
#                                                              'Blvd',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '4900 '
#                                                                   'Mueller '
#                                                                   'Blvd, '
#                                                                   'Austin, TX, '
#                                                                   '78723',
#                                               'locality': 'Austin',
#                                               'postalCode': '78723'},
#                                   'PhoneNumber': '(512) 324-0000',
#                                   'Website': 'https://healthcare.ascension.org/Locations/Texas/TXAUS/Austin-Dell-Childrens-Medical-Center',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [30.303455352783203,
#                                                                      -97.70735931396484],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': "Dell Children's Medical Center",
#                                   'point': {'coordinates': [30.303455352783203,
#                                                             -97.70735931396484],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '919 E 32nd St',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '919 E 32nd '
#                                                                   'St, Austin, '
#                                                                   'TX, 78705',
#                                               'locality': 'Austin',
#                                               'postalCode': '78705'},
#                                   'PhoneNumber': '(512) 476-7111',
#                                   'Website': 'https://stdavids.com/location/st-davids-medical-center',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [30.289552688598633,
#                                                                      -97.7254867553711],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': "St. David's Medical Center",
#                                   'point': {'coordinates': [30.289552688598633,
#                                                             -97.7254867553711],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '1313 Red River '
#                                                              'St Ste 100',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '1313 Red '
#                                                                   'River St '
#                                                                   'Ste 100, '
#                                                                   'Austin, TX, '
#                                                                   '78701',
#                                               'locality': 'Austin',
#                                               'postalCode': '78701'},
#                                   'PhoneNumber': '(512) 978-9610',
#                                   'Website': 'http://communitycaretx.org/',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [30.27422523498535,
#                                                                      -97.73468017578125],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Blackstock Family Health Center',
#                                   'point': {'coordinates': [30.27420997619629,
#                                                             -97.73509216308594],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '901 W Ben White '
#                                                              'Blvd',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '901 W Ben '
#                                                                   'White Blvd, '
#                                                                   'Austin, TX, '
#                                                                   '78704',
#                                               'locality': 'Austin',
#                                               'postalCode': '78704'},
#                                   'PhoneNumber': '(512) 447-2211',
#                                   'Website': 'https://stdavids.com/location/st-davids-south-austin-medical-center',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [30.226062774658203,
#                                                                      -97.77456665039062],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': "St. David's South Austin Medical "
#                                           'Center',
#                                   'point': {'coordinates': [30.226062774658203,
#                                                             -97.77456665039062],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '1709 Rio Grande '
#                                                              'St',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '1709 Rio '
#                                                                   'Grande St, '
#                                                                   'Austin, TX, '
#                                                                   '78701',
#                                               'locality': 'Austin',
#                                               'postalCode': '78701'},
#                                   'PhoneNumber': '(512) 374-9592',
#                                   'Website': 'http://www.birthwisetx.com/',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [30.281124114990234,
#                                                                      -97.74505615234375],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Birthwise Birth & Family Center',
#                                   'point': {'coordinates': [30.281185150146484,
#                                                             -97.74533081054688],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '1200 W Pecan St.',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '1200 W '
#                                                                   'Pecan St., '
#                                                                   'Pflugerville, '
#                                                                   'TX, 78660',
#                                               'locality': 'Pflugerville',
#                                               'postalCode': '78660'},
#                                   'PhoneNumber': '(512) 251-2275',
#                                   'Website': 'https://www.centraltexasanimalhospital.com/',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [30.44483184814453,
#                                                                      -97.62957000732422],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Central Texas Animal Hospital',
#                                   'point': {'coordinates': [30.444177627563477,
#                                                             -97.62997436523438],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '4315 James Casey '
#                                                              'Street, Suite '
#                                                              '200',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '4315 James '
#                                                                   'Casey '
#                                                                   'Street, '
#                                                                   'Suite 200, '
#                                                                   'Austin, TX, '
#                                                                   '78745',
#                                               'locality': 'Austin',
#                                               'postalCode': '78745'},
#                                   'PhoneNumber': '(512) 383-9752',
#                                   'Website': 'https://www.austinregionalclinic.com/clinics/arc-south-ob?utm_source=online-directory&utm_campaign=yext&utm_content=location-so-ob',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [30.223644256591797,
#                                                                      -97.7745132446289],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Austin Regional Clinic: ARC South '
#                                           'OB',
#                                   'point': {'coordinates': [30.223644256591797,
#                                                             -97.7745132446289],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '1220 Pkwy',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '1220 Pkwy, '
#                                                                   'Austin, TX, '
#                                                                   '78703',
#                                               'locality': 'Austin',
#                                               'postalCode': '78703'},
#                                   'PhoneNumber': '(512) 476-1069',
#                                   'Website': 'https://www.petclinicaustin.com/',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [30.278152465820312,
#                                                                      -97.75175476074219],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': "Highland's Pet Medical Clinic",
#                                   'point': {'coordinates': [30.278207778930664,
#                                                             -97.75154113769531],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '2401 S 31st St',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '2401 S 31st '
#                                                                   'St, Temple, '
#                                                                   'TX, 76508',
#                                               'locality': 'Temple',
#                                               'postalCode': '76508'},
#                                   'PhoneNumber': '(254) 724-2111',
#                                   'Website': 'https://www.bswhealth.com/locations/temple-clinic/',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [31.07794952392578,
#                                                                      -97.36383819580078],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Baylor Scott & White Medical Center '
#                                           '- Temple',
#                                   'point': {'coordinates': [31.07794952392578,
#                                                             -97.36383819580078],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '1301 Barbara '
#                                                              'Jordan Blvd #401',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '1301 '
#                                                                   'Barbara '
#                                                                   'Jordan Blvd '
#                                                                   '#401, '
#                                                                   'Austin, TX, '
#                                                                   '78723',
#                                               'locality': 'Austin',
#                                               'postalCode': '78723'},
#                                   'PhoneNumber': '(512) 628-1900',
#                                   'Website': 'https://healthcare.ascension.org/Locations/Texas/TXAUS/Austin-Dell-Childrens-Blood-Cancer-Center',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [30.305355072021484,
#                                                                      -97.70702362060547],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': "Dell Children's Blood & Cancer "
#                                           'Center',
#                                   'point': {'coordinates': [30.305355072021484,
#                                                             -97.70702362060547],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '1301 Barbara '
#                                                              'Jordan Blvd, '
#                                                              'Suite 100',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '1301 '
#                                                                   'Barbara '
#                                                                   'Jordan '
#                                                                   'Blvd, Suite '
#                                                                   '100, '
#                                                                   'Austin, TX, '
#                                                                   '78723',
#                                               'locality': 'Austin',
#                                               'postalCode': '78723'},
#                                   'PhoneNumber': '(512) 474-7337',
#                                   'Website': 'https://strictlypediatrics.com/',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [30.305356979370117,
#                                                                      -97.70703125],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Strictly Pediatrics Surgery Center',
#                                   'point': {'coordinates': [30.305356979370117,
#                                                             -97.70703125],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '5720 Menchaca Rd',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '5720 '
#                                                                   'Menchaca '
#                                                                   'Rd, Austin, '
#                                                                   'TX, 78745',
#                                               'locality': 'Austin',
#                                               'postalCode': '78745'},
#                                   'PhoneNumber': '(512) 442-6744',
#                                   'Website': 'http://mranimalhospital.com/',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [30.214651107788086,
#                                                                      -97.79962158203125],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Manchaca Road Animal Hospital',
#                                   'point': {'coordinates': [30.21432113647461,
#                                                             -97.79949188232422],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '313 E 12th St',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '313 E 12th '
#                                                                   'St, Austin, '
#                                                                   'TX, 78701',
#                                               'locality': 'Austin',
#                                               'postalCode': '78701'},
#                                   'PhoneNumber': '(512) 324-9650',
#                                   'Website': 'https://healthcare.ascension.org/Locations/Texas/TXAUS/Austin-University-of-Texas-Physicians-Downtown-Austin',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [30.272655487060547,
#                                                                      -97.73766326904297],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'University of Texas Physicians - '
#                                           'Downtown Austin',
#                                   'point': {'coordinates': [30.272655487060547,
#                                                             -97.73766326904297],
#                                             'type': 'Point'}},
#                                  {'Address': {'addressLine': '1215 E Court St',
#                                               'adminDistrict': 'TX',
#                                               'countryRegion': 'US',
#                                               'formattedAddress': '1215 E '
#                                                                   'Court St, '
#                                                                   'Seguin, TX, '
#                                                                   '78155',
#                                               'locality': 'Seguin',
#                                               'postalCode': '78155'},
#                                   'PhoneNumber': '(830) 379-2411',
#                                   'Website': 'https://www.grmedcenter.com/',
#                                   '__type': 'SearchResult:http://schemas.microsoft.com/search/local/ws/rest/v1',
#                                   'entityType': 'LocalBusiness',
#                                   'geocodePoints': [{'calculationMethod': 'Rooftop',
#                                                      'coordinates': [29.567913055419922,
#                                                                      -97.94619750976562],
#                                                      'type': 'Point',
#                                                      'usageTypes': ['Display']}],
#                                   'name': 'Guadalupe Regional Medical Center',
#                                   'point': {'coordinates': [29.567913055419922,
#                                                             -97.94619750976562],
#                                             'type': 'Point'}}]}],
#  'statusCode': 200,
#  'statusDescription': 'OK',
#  'traceId': 'a534041770f748c986a122ae495a5b75|CH0000108A|0.0.0.0'}

# %%
hospitals = call.json()['resourceSets'][0]['resources']

#pprint.pprint(hospitals)
print(hospitals[1]['point']['coordinates'])
print(hospitals[1]['name'])
# Out:
# [30.246864318847656, -97.77732849121094]
# Bluebonnet Animal Hospital

# %%
# Extract hosipital info
hospital_coords = []
hospital_names = []

for h in hospitals:
    name = h['name']
    hospital_names.append(name)
    
    coord = h['point']['coordinates']
    flipped_coord = [coord[1], coord[0]]
    hospital_coords.append(flipped_coord)

    
pprint.pprint(hospital_coords)
pprint.pprint(hospital_names)
# Out:
# [[-97.80225372314453, 30.23076629638672],
#  [-97.77732849121094, 30.246864318847656],
#  [-97.80033111572266, 30.17304229736328],
#  [-97.68097686767578, 30.61981201171875],
#  [-97.73481750488281, 30.275590896606445],
#  [-98.17084503173828, 29.72076416015625],
#  [-97.6845932006836, 30.332632064819336],
#  [-97.76069641113281, 30.375274658203125],
#  [-97.74609375, 30.304731369018555],
#  [-97.70735931396484, 30.303455352783203],
#  [-97.7254867553711, 30.289552688598633],
#  [-97.73509216308594, 30.27420997619629],
#  [-97.77456665039062, 30.226062774658203],
#  [-97.74533081054688, 30.281185150146484],
#  [-97.62997436523438, 30.444177627563477],
#  [-97.7745132446289, 30.223644256591797],
#  [-97.75154113769531, 30.278207778930664],
#  [-97.36383819580078, 31.07794952392578],
#  [-97.70702362060547, 30.305355072021484],
#  [-97.70703125, 30.305356979370117],
#  [-97.79949188232422, 30.21432113647461],
#  [-97.73766326904297, 30.272655487060547],
#  [-97.94619750976562, 29.567913055419922]]
# ['Westgate Pet & Bird Hospital',
#  'Bluebonnet Animal Hospital',
#  'South Park Animal Hospital',
#  'Georgetown Veterinary Hospital',
#  'Dell Seton Medical Center at The University of Texas',
#  'Two Rivers Eye Care',
#  'Animal Medical Center of Austin',
#  'Spicewood Springs Animal',
#  'Ascension Seton Medical Center Austin',
#  "Dell Children's Medical Center",
#  "St. David's Medical Center",
#  'Blackstock Family Health Center',
#  "St. David's South Austin Medical Center",
#  'Birthwise Birth & Family Center',
#  'Central Texas Animal Hospital',
#  'Austin Regional Clinic: ARC South OB',
#  "Highland's Pet Medical Clinic",
#  'Baylor Scott & White Medical Center - Temple',
#  "Dell Children's Blood & Cancer Center",
#  'Strictly Pediatrics Surgery Center',
#  'Manchaca Road Animal Hospital',
#  'University of Texas Physicians - Downtown Austin',
#  'Guadalupe Regional Medical Center']

# %%
# Filter hospitals by cleaning search results

i = len(hospital_names) - 1

while(i >= 0):
    name =  hospital_names[i]
    
    # Remove animal hospitals
    if("Animal" in name or "Veterinary" in name or "Pet" in name):
        del hospital_names[i]
        del hospital_coords[i]

    # Remove specialized facilities
    if("Education" in name or "Disorder" in name or "Birth" in name):
        del hospital_names[i]
        del hospital_coords[i]

    i -= 1
    
pprint.pprint(hospital_coords)
pprint.pprint(hospital_names)
# Out:
# [[-97.73481750488281, 30.275590896606445],
#  [-98.17084503173828, 29.72076416015625],
#  [-97.74609375, 30.304731369018555],
#  [-97.70735931396484, 30.303455352783203],
#  [-97.7254867553711, 30.289552688598633],
#  [-97.73509216308594, 30.27420997619629],
#  [-97.77456665039062, 30.226062774658203],
#  [-97.7745132446289, 30.223644256591797],
#  [-97.36383819580078, 31.07794952392578],
#  [-97.70702362060547, 30.305355072021484],
#  [-97.70703125, 30.305356979370117],
#  [-97.73766326904297, 30.272655487060547],
#  [-97.94619750976562, 29.567913055419922]]
# ['Dell Seton Medical Center at The University of Texas',
#  'Two Rivers Eye Care',
#  'Ascension Seton Medical Center Austin',
#  "Dell Children's Medical Center",
#  "St. David's Medical Center",
#  'Blackstock Family Health Center',
#  "St. David's South Austin Medical Center",
#  'Austin Regional Clinic: ARC South OB',
#  'Baylor Scott & White Medical Center - Temple',
#  "Dell Children's Blood & Cancer Center",
#  'Strictly Pediatrics Surgery Center',
#  'University of Texas Physicians - Downtown Austin',
#  'Guadalupe Regional Medical Center']

# %%
# Save results to csv

hospital_locations = np.array(hospital_coords)
dataset = pd.DataFrame({'hospital_names': hospital_names, "longitude": hospital_locations[:,0], "latitude": hospital_locations[:,1]})
print(dataset)

dataset.to_csv('hospitals.csv', index = False)
# Out:
#                                        hospital_names  longitude   latitude
# 0   Dell Seton Medical Center at The University of... -97.734818  30.275591
# 1                                 Two Rivers Eye Care -98.170845  29.720764
# 2               Ascension Seton Medical Center Austin -97.746094  30.304731
# 3                      Dell Children's Medical Center -97.707359  30.303455
# 4                          St. David's Medical Center -97.725487  30.289553
# 5                     Blackstock Family Health Center -97.735092  30.274210
# 6             St. David's South Austin Medical Center -97.774567  30.226063
# 7                Austin Regional Clinic: ARC South OB -97.774513  30.223644
# 8        Baylor Scott & White Medical Center - Temple -97.363838  31.077950
# 9               Dell Children's Blood & Cancer Center -97.707024  30.305355
# 10                 Strictly Pediatrics Surgery Center -97.707031  30.305357
# 11   University of Texas Physicians - Downtown Austin -97.737663  30.272655
# 12                  Guadalupe Regional Medical Center -97.946198  29.567913

# %% [markdown]
# ## Batch calls of distance matrix

# %%
# Prepare data for api call

#locations = region_coords
locations = region_coords + ems_coords + hospital_coords
durations = []

#pprint.pprint(locations)
print(len(locations))
# Out:
# 456

# %%
batch_size = 7
num_batches = math.ceil(len(locations) / batch_size)
remainder = len(locations) % batch_size

print(num_batches)
# Out:
# 66

# %%
headers = {
    'Accept': 'application/json, application/geo+json, application/gpx+xml, img/png; charset=utf-8',
    'Authorization': '5b3ce3597851110001cf624884518d9d4075408e95e3401165976247',
    'Content-Type': 'application/json; charset=utf-8'
}

# %%
for i in range(num_batches):
    print("batch ", i)
    start = i * batch_size
    sources = list(range(start, start + batch_size))
    
    # handle last partial batch
    if(sources[batch_size - 1] >= len(locations)):
        sources = sources[:remainder]
    
    body = {"locations": locations, "sources": sources}
    call = requests.post('https://api.openrouteservice.org/v2/matrix/driving-car', json=body, headers=headers)
    
    duration_batch = call.json()['durations']
    for j in range(len(duration_batch)):
        durations.append(duration_batch[j])
        
    time.sleep(2)
    
pprint.pprint(durations)
# Out:
# batch  0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-199a76a0c66c> in <module>
#      11     call = requests.post('https://api.openrouteservice.org/v2/matrix/driving-car', json=body, headers=headers)
#      12
# ---> 13     duration_batch = call.json()['durations']
#      14     for j in range(len(duration_batch)):
#      15         durations.append(duration_batch[j])
#
# KeyError: 'durations'

# %%
print(len(durations), len(durations[0]))
# Out:
# 455 455

# %%
np.savetxt("durations3.csv", np.array(durations), delimiter=",", fmt="%s")
